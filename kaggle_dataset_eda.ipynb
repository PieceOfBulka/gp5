# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/lyrics_10k.csv',index_col=0)

# %%
df.head()
# Out:
#                                 song_id  \
# 0  spotify:track:1NbzT9otocflZ9d8yvA54D
# 1  spotify:track:1crTf4RvraCjcPoqsaT9hd
# 2  spotify:track:4AGkBc4BiGLQNBdTUmUeF3
# 3  spotify:track:4jtIeveEJPs8SxuVa3FV21
# 4  spotify:track:5Dbr7Fy5VhSTXRbt2h3EYF
#
#                                artist_id                     song  \
# 0  spotify:artist:30TrHDLNCKQVTYWOn9QqOC         Better Than Home
# 1  spotify:artist:4P0dddbxPil35MNN9G2MEX                Illusions
# 2  spotify:artist:2sG4zTOLvjKG1PSoOyf5Ej      Touching the Ground
# 3  spotify:artist:0c173mlxpT3dSFRgMO8XPh  Nothing Is Stopping You
# 4  spotify:artist:4TKTii6gnOnUXQHyuo9JaD          I Shall Believe
#
#               artists  explicit  \
# 0       ['Beth Hart']     False
# 1    ['Cypress Hill']      True
# 2  ['Brandi Carlile']     False
# 3        ['Big Sean']      True
# 4     ['Sheryl Crow']     False
#
#                                               genres  \
# 0                                       modern blues
# 1  chicano rap;gangster rap;hardcore hip hop;hip ...
# 2  acoustic pop;folk;indie pop;lilith;modern folk...
# 3  detroit hip hop;hip hop;pop;pop rap;rap;southe...
# 4  lilith;mellow gold;neo mellow;new wave pop;per...
#
#                                               lyrics
# 0  Better than home Lyrics I can feel my body bre...
# 1  Illusions Lyrics Some people tell me that I ne...
# 2  Touching the Ground Lyrics I swear when we tou...
# 3  Nothing Is Stopping You Lyrics Nothing is stop...
# 4  I Shall Believe Lyrics Come to me now And lay ...

# %%
df[df['lyrics'].str.contains('Embed')].iloc[0]['lyrics']
# Out:
# "Better than home Lyrics I can feel my body breathing I can feel my heart is moving fast I am not afraid or lonely I am not chasing the ghosts of the past I have found the place where hunger Meets the edge and now I'm facing God I won't dare look into his eyes I can only hang my head to the ground When I try and open my mouth There's so many words but there's no sound And the angel comes upon me And the love I feel's a love I've never known And it's better than home Better than home Out on this long and winding road Chasing the sound with my friends And we ain't never rolling back again And who knows what we're gonna find Knows what we're gonna see Knows how we're gonna change Knows what we're gonna be Baby it's just you and me So keep driving on Cause this is better than home Everything inside me is stirring In every corner of every secret wound In the light I am adoring Feel like flying in circles around the moon When I gaze upon the world I know that I'm a part of something good I knew that I could And it's a love I've never known Better than home This is better than home Out on this long and winding road Chasing the sound with my friends And we ain't ever coming back again Yeah  who knows what we're gonna find Knows what we're gonna see Knows how we're gonna change Knows what we 're gonna be Baby it's just you and me So keep driving on Cause this is better than home This is better than home This is better than home You might also like Embed"

# %%
df.shape
# Out:
# (8674, 7)

# %% [markdown]
# ## Дубликаты

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# но этот 0 может означать только то, что у нас нет полных дубликатов (строчки, у которых совпадают абсолютно все признаки). Надо посмотреть дубликаты по названиям песни или название песни + артист. Важно выбрать именно второй вариант - так как существуют песни с одинаковым названием у разных исполнителей (например - Hello есть у Adele, Lionel Richie, Martin Solveig, Eminem и Evanescence)

# %%
df[['song','artists']].duplicated().sum()
# Out:
# np.int64(1990)

# %% [markdown]
# вот и ловушка метода duplicated с дефолтными параметрами - у нас аж 1990 потенциальных дубликатов.

# %%
duplicats = df[df[['song','artists']].duplicated(keep=False)].sort_values('song')
duplicats
# Out:
#                                    song_id  \
# 1305  spotify:track:2EW8oHPex1xcGOTLcjgAhq
# 5163  spotify:track:2S62u9h7ea1zxstVQWFaA5
# 4347  spotify:track:63pDgNA2K9O5NY9SathH0q
# 5334  spotify:track:1YpeognS6DsZSi8qx1U4Ya
# 5223  spotify:track:6t22B6AkDKzc855JzQJPfh
# ...                                    ...
# 3949  spotify:track:7kt9e9LFSpN1zQtYEl19o1
# 876   spotify:track:4wKsj88mt0ZRKCmOx8BRlu
# 324   spotify:track:5U0MyuuCoOoniHLQFLazLF
# 34    spotify:track:58P060mo9WWgEAdDvf0Riz
# 5875  spotify:track:2rtvt2O0Ypg6VL4tUgxnB6
#
#                                   artist_id                song  \
# 1305  spotify:artist:1Yox196W7bzVNZI7RBaPnf  1000 Times Goodbye
# 5163  spotify:artist:1Yox196W7bzVNZI7RBaPnf  1000 Times Goodbye
# 4347  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3                2024
# 5334  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3                2024
# 5223  spotify:artist:3q7HBObVc0L8jNeTe5Gofh        21 Questions
# ...                                     ...                 ...
# 3949  spotify:artist:06HL4z0CvFAxyc27GXpf02   this is me trying
# 876   spotify:artist:06HL4z0CvFAxyc27GXpf02         tolerate it
# 324   spotify:artist:06HL4z0CvFAxyc27GXpf02         tolerate it
# 34    spotify:artist:06HL4z0CvFAxyc27GXpf02              willow
# 5875  spotify:artist:06HL4z0CvFAxyc27GXpf02              willow
#
#                        artists  explicit  \
# 1305              ['Megadeth']     False
# 5163              ['Megadeth']     False
# 4347     ['Cage The Elephant']     False
# 5334     ['Cage The Elephant']     False
# 5223  ['50 Cent', 'Nate Dogg']     False
# ...                        ...       ...
# 3949          ['Taylor Swift']     False
# 876           ['Taylor Swift']      True
# 324           ['Taylor Swift']     False
# 34            ['Taylor Swift']     False
# 5875          ['Taylor Swift']     False
#
#                                                  genres  \
# 1305  alternative metal;hard rock;melodic thrash;met...
# 5163  alternative metal;hard rock;melodic thrash;met...
# 4347                        modern rock;punk blues;rock
# 5334                        modern rock;punk blues;rock
# 5223  east coast hip hop;gangster rap;hip hop;pop ra...
# ...                                                 ...
# 3949                                                pop
# 876                                                 pop
# 324                                                 pop
# 34                                                  pop
# 5875                                                pop
#
#                                                  lyrics
# 1305  1000 Times Goodbye Lyrics The tides of change ...
# 5163  1000 Times Goodbye Lyrics The tides of change ...
# 4347  2024 Lyrics Fall into that black hole  honey L...
# 5334  2024 Lyrics Fall into that black hole  honey L...
# 5223  Translations Русский Português50 Cent - 21 Que...
# ...                                                 ...
# 3949  Translations Nederlands Türkçe Español Српски ...
# 876   Translations Türkçe Español Română Português I...
# 324   Translations Türkçe Español Română Português I...
# 34    Translations Türkçe Español Српски Română Port...
# 5875  Translations Türkçe Español Српски Română Port...
#
# [3445 rows x 7 columns]

# %%
df[['song','explicit','genres','lyrics']].duplicated().sum()
# Out:
# np.int64(1598)

# %% [markdown]
# Было предположение, что эти дубликаты отличаются только по id - однако не все (только 1598 из 1990 поддаются этой логике).

# %%
duplicats_diff = duplicats[['song','explicit','genres','lyrics']].groupby('song').nunique()
duplicats_diff
# Out:
#                                  explicit  genres  lyrics
# song
# 1000 Times Goodbye                      1       1       1
# 2024                                    1       1       1
# 21 Questions                            2       1       1
# 24K Magic                               1       1       2
# 2step                                   1       1       1
# ...                                   ...     ...     ...
# the 1                                   1       1       2
# the last great american dynasty         2       1       2
# this is me trying                       1       1       1
# tolerate it                             2       1       2
# willow                                  1       1       1
#
# [1420 rows x 3 columns]

# %%
duplicats_diff.max()
# Out:
# explicit    2
# genres      5
# lyrics      5
# dtype: int64

# %% [markdown]
# то есть различия в дубликатах могут быть по всем колонкам, кроме explicit

# %%
duplicats_diff[duplicats_diff.max(axis=1)>1]
# Out:
#                                  explicit  genres  lyrics
# song
# 21 Questions                            2       1       1
# 24K Magic                               1       1       2
# 32-20 Blues                             1       1       2
# 36                                      2       1       1
# 4KT Baby                                2       1       1
# ...                                   ...     ...     ...
# pick up the phone                       2       1       1
# skin                                    1       1       2
# the 1                                   1       1       2
# the last great american dynasty         2       1       2
# tolerate it                             2       1       2
#
# [465 rows x 3 columns]

# %%
duplicats_count = duplicats.groupby(['song','artists'])['song_id'].count()
duplicats_count
# Out:
# song                             artists
# 1000 Times Goodbye               ['Megadeth']                2
# 2024                             ['Cage The Elephant']       2
# 21 Questions                     ['50 Cent', 'Nate Dogg']    2
# 24K Magic                        ['Bruno Mars']              2
# 2step                            ['Ed Sheeran']              8
#                                                             ..
# the 1                            ['Taylor Swift']            2
# the last great american dynasty  ['Taylor Swift']            2
# this is me trying                ['Taylor Swift']            2
# tolerate it                      ['Taylor Swift']            2
# willow                           ['Taylor Swift']            2
# Name: song_id, Length: 1455, dtype: int64

# %%
duplicats_count.max() # максимальное кол-во дубликатов
# Out:
# np.int64(9)

# %%
duplicats_count[duplicats_count==duplicats_count.max()]
# Out:
# song      artists
# Bonita    ['GIMS']                9
# Clap      ['Armin van Buuren']    9
# Tant pis  ['GIMS']                9
# Name: song_id, dtype: int64

# %%
duplicats_diff[duplicats_diff['genres']>duplicats_diff['lyrics']]
# Out:
# Empty DataFrame
# Columns: [explicit, genres, lyrics]
# Index: []

# %%
duplicats_diff[duplicats_diff['genres']<duplicats_diff['lyrics']]
# Out:
#                                  explicit  genres  lyrics
# song
# 24K Magic                               1       1       2
# 32-20 Blues                             1       1       2
# A Change Would Do You Good              1       1       2
# A Milli                                 1       1       2
# ABOUT YOU                               2       1       2
# ...                                   ...     ...     ...
# mirrorball                              1       1       2
# skin                                    1       1       2
# the 1                                   1       1       2
# the last great american dynasty         2       1       2
# tolerate it                             2       1       2
#
# [239 rows x 3 columns]

# %% [markdown]
# Почему так получилось, что у нас одна и та же песня могла попасть в датасет несколько раза и с разными айдишниками?
# Предположения:
# - песня внутри альбома, сборника или в поиске - разные цифровые объекты, которые как раз и отличаются только по id. Это проблемы парсинга
# - разные правила на дистрибуцию музыки в разных регионах - следовательно под каждый регион создается свой цифровой объект песни с нужными правами
#
# Почему так получилось, что у нас одна и та же песня могла попасть в датасет несколько раза и с разными жанрами?
# Ответ: вспомним тот пример с песней Hello - с таким названием есть треки у многих - то есть это все же разные песни (то есь они и текстом отличаются и жанром).
#
# Также выследилось правило: количество песен в жанре меньше или равно количеству по тексту. Почему?
# Мы прибегаем к второму пункты первого вопроса: разные регионы - разные правила, то есть разная цензура.
#
# В итоге - мы удаляем песни-дубликаты ВСЕ. Оставляем только первое вхождение песни, у которой есть дубликат (это одна из версий песни для какого-то региона)

# %%
df.shape
# Out:
# (8613, 7)

# %%
df = df[~df[['song','artists']].duplicated()]

# %%
df.shape
# Out:
# (6623, 7)

# %% [markdown]
# ## Пропуски

# %%
df.isna().sum()
# Out:
# song_id       0
# artist_id     0
# song          0
# artists       0
# explicit      0
# genres       61
# lyrics        0
# dtype: int64

# %% [markdown]
# ## Анализ жанров

# %%
df[df['genres'].isna()]
# Out:
#                                    song_id  \
# 176   spotify:track:3pf9eIGYFtIlL2UnJqFsrG
# 214   spotify:track:5SDIN7Z1SZMdRYVpx7abaA
# 266   spotify:track:6Jln2IgzM0RGlqZy9Igx1W
# 550   spotify:track:6l2JdUq3mM5F1pwXQ6uZaT
# 688   spotify:track:1lCNiqX329mUgg9b8UXyCY
# ...                                    ...
# 7936  spotify:track:3ibBCn5TTwlBBP6DPKkmJu
# 8038  spotify:track:5rBSaj8VjtrdQzIDrGXJ4l
# 8340  spotify:track:7bEEce1Wwo18iItGQHa1No
# 8412  spotify:track:7AQ7rZz3kRWLct1NpIxEnc
# 8455  spotify:track:3Pg7TLUW4HSgO1nQx3Uupn
#
#                                   artist_id                    song  \
# 176   spotify:artist:0KuF7reCTOZwV7YJnHQqgr                   Intro
# 214   spotify:artist:7n5xb6bByE74Aw4ppe858H                For Chan
# 266   spotify:artist:4gKo3LXoxHriLS6CBKThAU           Touch the Sky
# 550   spotify:artist:1hckaudcoOzWyeRIlrOksc                 Shut Up
# 688   spotify:artist:7n5xb6bByE74Aw4ppe858H     Get Back Down To Me
# ...                                     ...                     ...
# 7936  spotify:artist:6rJtd5E1XqdQiphzXDX6UT  Standing on the Corner
# 8038  spotify:artist:2Ve76xf8WEVRRfanpQHgLs                Carry On
# 8340  spotify:artist:7n5xb6bByE74Aw4ppe858H         Ghost in My Bed
# 8412  spotify:artist:1hckaudcoOzWyeRIlrOksc                Redlight
# 8455  spotify:artist:6PjDCeZZmEgmlenl4Bf5Pr                    NYLA
#
#                                                 artists  explicit genres  \
# 176                                    ['The Neptunes']      True    NaN
# 214                                   ['Tim Heidecker']     False    NaN
# 266   ['MALINDA', {'label': 'spotify:artist:3peB3IJ4...     False    NaN
# 550                                  ['Kelly Osbourne']     False    NaN
# 688                                   ['Tim Heidecker']     False    NaN
# ...                                                 ...       ...    ...
# 7936                               ['Andrew Stockdale']     False    NaN
# 8038                                 ['Sebastian Kole']     False    NaN
# 8340                                  ['Tim Heidecker']     False    NaN
# 8412                                 ['Kelly Osbourne']     False    NaN
# 8455  ['Fancy Feelings', {'label': 'spotify:artist:6...     False    NaN
#
#                                                  lyrics
# 176   Intro Lyrics1  2  3  41  2  3  41  2  3  4  1C...
# 214   For Chan Lyrics I am only one man but my words...
# 266   Touch the Sky Lyrics When the cold wind is a-c...
# 550   Shut Up Lyrics You say I should do it differen...
# 688   Get Back Down To Me Lyrics Take that One  two ...
# ...                                                 ...
# 7936  Standing on the Corner Lyrics Standing on the ...
# 8038  Carry On Lyrics I walk the streets uncertain o...
# 8340  Ghost in My Bed Lyrics I put your head in a pl...
# 8412  Redlight Lyrics Im falling  dont bother  i rat...
# 8455  NYLA Lyrics New York  LABack to New York again...
#
# [61 rows x 7 columns]

# %%
df.shape
# Out:
# (8674, 7)

# %%
# так как нашей целевой переменной является жанр - то записи с пропуском в поле genres нам абсолютно бесполезны, следовательно их можно удалить
df = df[~df['genres'].isna()]

# %%
df.shape
# Out:
# (8613, 7)

# %%
genres_exploded = df['genres'].str.split(';').explode()

# %%
genres_exploded
# Out:
# 0           modern blues
# 1            chicano rap
# 1           gangster rap
# 1       hardcore hip hop
# 1                hip hop
#               ...
# 8672           dance pop
# 8672                 pop
# 8672       post-teen pop
# 8673         chicago rap
# 8673                 rap
# Name: genres, Length: 39233, dtype: str

# %%
genres_counts = genres_exploded.value_counts()
genres_counts
# Out:
# genres
# rock            1811
# rap             1757
# pop             1488
# hip hop         1398
# classic rock     992
#                 ...
# finnish edm        1
# disco house        1
# tech house         1
# tribal house       1
# vocal house        1
# Name: count, Length: 391, dtype: int64

# %%
plt.plot(genres_counts.values)
plt.xlabel('Количество таких значений')
plt.ylabel('Значения встречаемости жанра')
plt.show()

# %%
top100 = genres_counts.head(100)
top100
# Out:
# genres
# rock                1811
# rap                 1757
# pop                 1488
# hip hop             1398
# classic rock         992
#                     ...
# dmv rap               95
# canadian hip hop      95
# toronto rap           95
# dutch trance          92
# trance                92
# Name: count, Length: 100, dtype: int64

# %%
# выбираем только топ 100 жанров по встречаемсоти
top100.to_csv('data/genres_top.csv')

# %% [markdown]
# ## Анализ артистов

# %%
df[df['artists'].str.contains(',')]
# Out:
#                                    song_id  \
# 13    spotify:track:1pNhY2t3jiVv9cEuJEHlia
# 20    spotify:track:3xrYWpqTNDL1shQTs5LPtq
# 35    spotify:track:23ao5xmZllnMj5OSEYN7cp
# 37    spotify:track:4Zj3K3UaUMC6ndSwl05Zyd
# 66    spotify:track:7jDkOdfBy7D5MJVKCxQQ2J
# ...                                    ...
# 8640  spotify:track:0N9YlRBgUjjvgCtklmkKIH
# 8648  spotify:track:13Mh55MPFYy2O6uby9061n
# 8654  spotify:track:0ZelN6FXKczKZQidKpOLAq
# 8659  spotify:track:7Dclmopi4DlzmMqVEyHzG8
# 8673  spotify:track:3DK6m7It6Pw857FcQftMds
#
#                                   artist_id                      song  \
# 13    spotify:artist:0GOx72r5AAEKRGQFn3xqXK                      Oats
# 20    spotify:artist:4P0dddbxPil35MNN9G2MEX                   Audio X
# 35    spotify:artist:6BrvowZBreEkXzJQMpL174  Nothing Can Hold Us Down
# 37    spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5                  Bellacon
# 66    spotify:artist:17lzZA2AlOHwCwFALHttmp         Extremely Blessed
# ...                                     ...                       ...
# 8640  spotify:artist:6MTByljF8u5omBltY2VKPU     Breathing Under Water
# 8648  spotify:artist:55Aa2cqylxrFIXC767Z865             Shoot Me Down
# 8654  spotify:artist:22bukBZvUppuwQwmDz75Gz                    Eagles
# 8659  spotify:artist:6PAt558ZEZl0DmdXlnjMgD               I Feel Free
# 8673  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x                   Runaway
#
#                                                 artists  explicit  \
# 13    ['GIMS', {'label': 'spotify:artist:3i2AdhSP4Ye...     False
# 20    ['Cypress Hill', {'label': 'spotify:artist:7zs...      True
# 35    ['Hardwell', {'label': 'spotify:artist:6C0KWmC...     False
# 37    ['J Balvin', {'label': 'spotify:artist:2oQX8Qi...     False
# 66    ['2 Chainz', {'label': 'spotify:artist:1W3FSF1...      True
# ...                                                 ...       ...
# 8640                 ['Anoushka Shankar', 'Karsh Kale']     False
# 8648  ['Lil Wayne', {'label': 'spotify:artist:0SINQM...      True
# 8654  ['Sander van Doorn', {'label': 'spotify:artist...     False
# 8659  ['Eric Clapton', {'label': 'spotify:artist:74o...     False
# 8673  ['Kanye West', {'label': 'spotify:artist:0ONHk...      True
#
#                                                  genres  \
# 13    francoton;french hip hop;french pop;rap conscient
# 20    chicano rap;gangster rap;hardcore hip hop;hip ...
# 35    big room;dance pop;dutch house;edm;electro hou...
# 37         reggaeton;reggaeton colombiano;urbano latino
# 66    atl hip hop;gangster rap;hip hop;pop rap;rap;s...
# ...                                                 ...
# 8640             indian fusion;sitar;world;world fusion
# 8648           hip hop;new orleans rap;pop rap;rap;trap
# 8654  dutch trance;edm;electro house;house;pop dance...
# 8659        blues rock;classic rock;electric blues;rock
# 8673                                    chicago rap;rap
#
#                                                  lyrics
# 13    OATS Lyrics Yeah  yeah Yeah  yeah Yeah  yeah J...
# 20    Audio X Lyrics"T-Minus 10  9  8  7  6.. 5  4  ...
# 35    Nothing Can Hold Us Down Lyrics Oceans' red is...
# 37    Bellacon Lyrics Tú me tienes bellacón  bellacó...
# 66    Extremely Blessed Lyrics Baby let's roll away ...
# ...                                                 ...
# 8640  Breathing Under Water Lyrics This song is perf...
# 8648  Shoot Me Down Lyrics Open up your hearts  peop...
# 8654  Eagles Lyrics Eager like fever  burning when I...
# 8659  I Feel Free Lyrics Feel when I dance with you ...
# 8673  Translations Türkçe Português English English ...
#
# [1505 rows x 7 columns]

# %% [markdown]
# ## Анализ языка текста

# %%
df[df['lyrics'].str.len()==0]
# Out:
# Empty DataFrame
# Columns: [song_id, artist_id, song, artists, explicit, genres, lyrics]
# Index: []

# %%
from langdetect import detect

# %%
languages = df['lyrics'].apply(lambda x: detect(str(x)))

# %%
languages.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='lyrics'>

# %%
languages[languages!='en'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='lyrics'>

# %%
set(languages)
# Out:
# {'af',
#  'ca',
#  'da',
#  'de',
#  'en',
#  'es',
#  'et',
#  'fr',
#  'hi',
#  'hr',
#  'id',
#  'it',
#  'ja',
#  'ko',
#  'nl',
#  'no',
#  'pt',
#  'so',
#  'sq',
#  'sw',
#  'tl'}

# %%
df[languages!='en']
# Out:
#                                    song_id  \
# 13    spotify:track:1pNhY2t3jiVv9cEuJEHlia
# 37    spotify:track:4Zj3K3UaUMC6ndSwl05Zyd
# 39    spotify:track:0tH73cQ8wWggprTskasQqy
# 53    spotify:track:3Fy8eG3j2aPZ47bOlUtYhM
# 79    spotify:track:65jQEJX36oXm7LLUbe5ISK
# ...                                    ...
# 8483  spotify:track:2U31dTDQT1nPRydCxGWRIG
# 8507  spotify:track:5EW1Rlt4Hqc4eEMnIn3tEB
# 8571  spotify:track:2ywkj6sjyVBmq46wgIgIlw
# 8604  spotify:track:1I77XVl7wCTxJFwbWsQodh
# 8629  spotify:track:4F0B8TLdJVACskfkkTqHDI
#
#                                   artist_id                      song  \
# 13    spotify:artist:0GOx72r5AAEKRGQFn3xqXK                      Oats
# 37    spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5                  Bellacon
# 39    spotify:artist:5iksmHDN2qZQcgFfXqIXtT  Hasta Siempre Comandante
# 53    spotify:artist:2hejA1Dkf8v8R0koF44FvW                 Dos Caras
# 79    spotify:artist:0UWZUmn7sybxMCqrw9tGa7               Radio Elvis
# ...                                     ...                       ...
# 8483  spotify:artist:0GOx72r5AAEKRGQFn3xqXK                  ONLY YOU
# 8507  spotify:artist:4boI7bJtmB1L3b1cuL75Zr                       Ana
# 8571  spotify:artist:4Ai0pGz6GhQavjzaRhPTvz                   Shehnai
# 8604  spotify:artist:4boI7bJtmB1L3b1cuL75Zr                 La Trenza
# 8629  spotify:artist:0GOx72r5AAEKRGQFn3xqXK                     Reste
#
#                                                 artists  explicit  \
# 13    ['GIMS', {'label': 'spotify:artist:3i2AdhSP4Ye...     False
# 37    ['J Balvin', {'label': 'spotify:artist:2oQX8Qi...     False
# 39                                     ['Robert Wyatt']     False
# 53                                          ['Gera MX']     False
# 79                                           ['Juanes']     False
# ...                                                 ...       ...
# 8483  ['GIMS', {'label': 'spotify:artist:6t7U7sYlVCt...     False
# 8507                                    ['Mon Laferte']     False
# 8571                                         ['DIVINE']     False
# 8604                                    ['Mon Laferte']     False
# 8629                                  ['Sting', 'GIMS']     False
#
#                                                  genres  \
# 13    francoton;french hip hop;french pop;rap conscient
# 37         reggaeton;reggaeton colombiano;urbano latino
# 39    art rock;british folk;canterbury scene;experim...
# 53                       mexican hip hop;rap conciencia
# 79    colombian pop;latin pop;mexican pop;rock en es...
# ...                                                 ...
# 8483  francoton;french hip hop;french pop;rap conscient
# 8507                                  latin alternative
# 8571               desi hip hop;desi trap;hindi hip hop
# 8604                                  latin alternative
# 8629  francoton;french hip hop;french pop;rap conscient
#
#                                                  lyrics
# 13    OATS Lyrics Yeah  yeah Yeah  yeah Yeah  yeah J...
# 37    Bellacon Lyrics Tú me tienes bellacón  bellacó...
# 39    Hasta Siempre Comandante Lyrics Aprendimos a q...
# 53    Dos Caras Lyrics Ouhh haha no veo no siento ye...
# 79    Radio Elvis Lyrics Con tu piel sobre mi piel y...
# ...                                                 ...
# 8483  ONLY YOU Lyrics Ah  ah  ah  ah Ton départ m'a ...
# 8507  Ana Lyrics¡Ana! No huyas de mí¿Por qué  Ana  c...
# 8571  Translations Romanization Shehnai Lyricsज़िन्दग...
# 8604  La trenza Lyrics Tú eres distinta a todas las ...
# 8629  Reste Lyrics Comme la lune  la nuit apparaît d...
#
# [306 rows x 7 columns]

# %%
df.shape
# Out:
# (6623, 7)

# %%
df = df[languages=='en']

# %%
df.shape
# Out:
# (6317, 7)

# %% [markdown]
# # Feature Engineering

# %%
df_final = df.copy()

# %% [markdown]
# ## Очистка текстов песен

# %%
import re
def clean_lyrics(text):
    if not text:
        return ''
    text=re.sub(r'^.*Lyrics','',text)
    text=re.sub(r'You might also like','',text,flags=re.IGNORECASE)
    text=text.strip()
    text=re.sub(r'\d*Embed$','',text)
    return text.strip()

# %%
df_final['lyrics'] = df_final['lyrics'].apply(clean_lyrics)

# %%
df.sample(5,random_state=42)
# Out:
#                                    song_id  \
# 5082  spotify:track:4dBJwClRPCWgBcVYI4XO3y
# 4734  spotify:track:4iepMhkLm7EA05yvTIM3Xt
# 774   spotify:track:4bDZJWd5tsjZxGGkVR2QFG
# 4461  spotify:track:3POYMPJ0HJGtBc7aO2H7QV
# 3140  spotify:track:168hzUkAHLNwg0Lo2ozGQB
#
#                                   artist_id                           song  \
# 5082  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR            Stronger Than I Was
# 4734  spotify:artist:68DWke2VjdDmA75aJX5C57                      Mud Mouth
# 774   spotify:artist:2lolQgalUvZDfp5vvVtTYV                    Blue Velvet
# 4461  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3                    Tokyo Smoke
# 3140  spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5  Computers Take over the World
#
#                     artists  explicit  \
# 5082             ['Eminem']      True
# 4734           ['Yelawolf']      True
# 774        ['Tony Bennett']     False
# 4461  ['Cage The Elephant']     False
# 3140   ['Armin van Buuren']     False
#
#                                                  genres  \
# 5082                        detroit hip hop;hip hop;rap
# 4734   alabama rap;hip hop;pop rap;rap;southern hip hop
# 774    adult standards;easy listening;lounge;vocal jazz
# 4461                        modern rock;punk blues;rock
# 3140  dutch trance;edm;pop dance;progressive house;t...
#
#                                                  lyrics
# 5082  Translations Türkçe Stronger Than I Was Lyrics...
# 4734  TranslationsفارسیMud Mouth Lyrics Yeah I feel ...
# 774   Blue Velvet Lyrics She wore Blue Velvet Bluer ...
# 4461  Tokyo Smoke Lyrics Hey man Hand me down with t...
# 3140  Computers Take Over The World Lyrics Hello  I ...

# %%
df_final.sample(5,random_state=42)
# Out:
#                                    song_id  \
# 5082  spotify:track:4dBJwClRPCWgBcVYI4XO3y
# 4734  spotify:track:4iepMhkLm7EA05yvTIM3Xt
# 774   spotify:track:4bDZJWd5tsjZxGGkVR2QFG
# 4461  spotify:track:3POYMPJ0HJGtBc7aO2H7QV
# 3140  spotify:track:168hzUkAHLNwg0Lo2ozGQB
#
#                                   artist_id                           song  \
# 5082  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR            Stronger Than I Was
# 4734  spotify:artist:68DWke2VjdDmA75aJX5C57                      Mud Mouth
# 774   spotify:artist:2lolQgalUvZDfp5vvVtTYV                    Blue Velvet
# 4461  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3                    Tokyo Smoke
# 3140  spotify:artist:0SfsnGyD8FpIN4U4WCkBZ5  Computers Take over the World
#
#                     artists  explicit  \
# 5082             ['Eminem']      True
# 4734           ['Yelawolf']      True
# 774        ['Tony Bennett']     False
# 4461  ['Cage The Elephant']     False
# 3140   ['Armin van Buuren']     False
#
#                                                  genres  \
# 5082                        detroit hip hop;hip hop;rap
# 4734   alabama rap;hip hop;pop rap;rap;southern hip hop
# 774    adult standards;easy listening;lounge;vocal jazz
# 4461                        modern rock;punk blues;rock
# 3140  dutch trance;edm;pop dance;progressive house;t...
#
#                                                  lyrics
# 5082  You used to say that I'd never be Nothin' with...
# 4734  Yeah I feel the breeze comin' in I smell the s...
# 774   She wore Blue Velvet Bluer than velvet was the...
# 4461  Hey man Hand me down with the crooked back Wha...
# 3140  Hello  I am your electronic dance music proces...

# %% [markdown]
# ## Обработка мультижанровости песни

# %%
df_final['genres'] = df_final['genres'].apply(lambda x: [genre.strip() for genre in str(x).strip().split(';') if genre.strip()])
df_final.head()
# Out:
#                                 song_id  \
# 0  spotify:track:1NbzT9otocflZ9d8yvA54D
# 1  spotify:track:1crTf4RvraCjcPoqsaT9hd
# 2  spotify:track:4AGkBc4BiGLQNBdTUmUeF3
# 3  spotify:track:4jtIeveEJPs8SxuVa3FV21
# 4  spotify:track:5Dbr7Fy5VhSTXRbt2h3EYF
#
#                                artist_id                     song  \
# 0  spotify:artist:30TrHDLNCKQVTYWOn9QqOC         Better Than Home
# 1  spotify:artist:4P0dddbxPil35MNN9G2MEX                Illusions
# 2  spotify:artist:2sG4zTOLvjKG1PSoOyf5Ej      Touching the Ground
# 3  spotify:artist:0c173mlxpT3dSFRgMO8XPh  Nothing Is Stopping You
# 4  spotify:artist:4TKTii6gnOnUXQHyuo9JaD          I Shall Believe
#
#               artists  explicit  \
# 0       ['Beth Hart']     False
# 1    ['Cypress Hill']      True
# 2  ['Brandi Carlile']     False
# 3        ['Big Sean']      True
# 4     ['Sheryl Crow']     False
#
#                                               genres  \
# 0                                     [modern blues]
# 1  [chicano rap, gangster rap, hardcore hip hop, ...
# 2  [acoustic pop, folk, indie pop, lilith, modern...
# 3  [detroit hip hop, hip hop, pop, pop rap, rap, ...
# 4  [lilith, mellow gold, neo mellow, new wave pop...
#
#                                               lyrics
# 0  I can feel my body breathing I can feel my hea...
# 1  Some people tell me that I need help Some peop...
# 2  I swear when we touched  I saw heaven in your ...
# 3  Nothing is stopping you Stopping you Stopping ...
# 4  Come to me now And lay your hands over me Even...

# %% [markdown]
# ## Обработка случае нескольких исполнителей у песни

# %%
df_final['artists'] = df_final['artists'].apply(lambda x: [artist.strip() for artist in str(x).replace('[','').replace(']','').replace("'",'').strip().split(',') if artist.strip()])
df_final.head()
# Out:
#                                 song_id  \
# 0  spotify:track:1NbzT9otocflZ9d8yvA54D
# 1  spotify:track:1crTf4RvraCjcPoqsaT9hd
# 2  spotify:track:4AGkBc4BiGLQNBdTUmUeF3
# 3  spotify:track:4jtIeveEJPs8SxuVa3FV21
# 4  spotify:track:5Dbr7Fy5VhSTXRbt2h3EYF
#
#                                artist_id                     song  \
# 0  spotify:artist:30TrHDLNCKQVTYWOn9QqOC         Better Than Home
# 1  spotify:artist:4P0dddbxPil35MNN9G2MEX                Illusions
# 2  spotify:artist:2sG4zTOLvjKG1PSoOyf5Ej      Touching the Ground
# 3  spotify:artist:0c173mlxpT3dSFRgMO8XPh  Nothing Is Stopping You
# 4  spotify:artist:4TKTii6gnOnUXQHyuo9JaD          I Shall Believe
#
#             artists  explicit  \
# 0       [Beth Hart]     False
# 1    [Cypress Hill]      True
# 2  [Brandi Carlile]     False
# 3        [Big Sean]      True
# 4     [Sheryl Crow]     False
#
#                                               genres  \
# 0                                     [modern blues]
# 1  [chicano rap, gangster rap, hardcore hip hop, ...
# 2  [acoustic pop, folk, indie pop, lilith, modern...
# 3  [detroit hip hop, hip hop, pop, pop rap, rap, ...
# 4  [lilith, mellow gold, neo mellow, new wave pop...
#
#                                               lyrics
# 0  I can feel my body breathing I can feel my hea...
# 1  Some people tell me that I need help Some peop...
# 2  I swear when we touched  I saw heaven in your ...
# 3  Nothing is stopping you Stopping you Stopping ...
# 4  Come to me now And lay your hands over me Even...

# %% [markdown]
# ## Оставляем топ100 популярных жанров

# %%
df_final.shape
# Out:
# (6317, 7)

# %%
df_final = df_final[df_final['genres'].apply(lambda x: any(genre in genres_counts.head(100) for genre in x))]

# %%
df_final.shape
# Out:
# (5778, 7)

# %%
df_final['genres'] = df_final['genres'].apply(lambda x: [genre for genre in x if genre in top100])

# %% [markdown]
# # Финальный датасет

# %%
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5778 entries, 1 to 8673
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   song_id    5778 non-null   str
#  1   artist_id  5778 non-null   str
#  2   song       5778 non-null   str
#  3   artists    5778 non-null   object
#  4   explicit   5778 non-null   bool
#  5   genres     5778 non-null   object
#  6   lyrics     5778 non-null   str
# dtypes: bool(1), object(2), str(4)
# memory usage: 321.6+ KB

# %%
df_final
# Out:
#                                    song_id  \
# 1     spotify:track:1crTf4RvraCjcPoqsaT9hd
# 2     spotify:track:4AGkBc4BiGLQNBdTUmUeF3
# 3     spotify:track:4jtIeveEJPs8SxuVa3FV21
# 4     spotify:track:5Dbr7Fy5VhSTXRbt2h3EYF
# 5     spotify:track:6QhsQvMgEuqJE6z7re1ijE
# ...                                    ...
# 8666  spotify:track:3XDl09T6fty3xbGSXASLT8
# 8668  spotify:track:6JbioaahWqp3efRZWN001d
# 8670  spotify:track:1yKLa9X63tBfvLojNOw9y8
# 8672  spotify:track:64kfyGcf5dvbw92Vv4THCj
# 8673  spotify:track:3DK6m7It6Pw857FcQftMds
#
#                                   artist_id                     song  \
# 1     spotify:artist:4P0dddbxPil35MNN9G2MEX                Illusions
# 2     spotify:artist:2sG4zTOLvjKG1PSoOyf5Ej      Touching the Ground
# 3     spotify:artist:0c173mlxpT3dSFRgMO8XPh  Nothing Is Stopping You
# 4     spotify:artist:4TKTii6gnOnUXQHyuo9JaD          I Shall Believe
# 5     spotify:artist:3EhbVgyfGd7HkpsagwL9GS            Why Trust You
# ...                                     ...                      ...
# 8666  spotify:artist:43O3c6wewpzPKwVaGEEtBM              New Morning
# 8668  spotify:artist:00FQb4jTyendYWaN8pK0wa                  Bel Air
# 8670  spotify:artist:50co4Is1HCEo8bhOyUWKpn                  Harambe
# 8672  spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx                      Fun
# 8673  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x                  Runaway
#
#                                                 artists  explicit  \
# 1                                        [Cypress Hill]      True
# 2                                      [Brandi Carlile]     False
# 3                                            [Big Sean]      True
# 4                                         [Sheryl Crow]     False
# 5                                        [Alice Cooper]     False
# ...                                                 ...       ...
# 8666                                [My Morning Jacket]     False
# 8668                                     [Lana Del Rey]     False
# 8670                                       [Young Thug]      True
# 8672                                     [Selena Gomez]     False
# 8673  [Kanye West, {label: spotify:artist:0ONHkAv9pC...      True
#
#                                                  genres  \
# 1     [chicano rap, gangster rap, hardcore hip hop, ...
# 2     [folk, indie pop, lilith, neo mellow, new amer...
# 3     [detroit hip hop, hip hop, pop, pop rap, rap, ...
# 4     [lilith, mellow gold, neo mellow, new wave pop...
# 5     [album rock, blues rock, classic rock, detroit...
# ...                                                 ...
# 8666  [alternative rock, blues rock, indie folk, ind...
# 8668                                     [art pop, pop]
# 8670  [atl hip hop, gangster rap, hip hop, melodic r...
# 8672                    [dance pop, pop, post-teen pop]
# 8673                                 [chicago rap, rap]
#
#                                                  lyrics
# 1     Some people tell me that I need help Some peop...
# 2     I swear when we touched  I saw heaven in your ...
# 3     Nothing is stopping you Stopping you Stopping ...
# 4     Come to me now And lay your hands over me Even...
# 5     You come on strong with a great big smile But ...
# ...                                                 ...
# 8666  Wakin' up feelin' good and limber When the tel...
# 8668  Gargoyles standing at the front of your gate T...
# 8670  Mafia Billboard Hitmakers Yeah  AP gang  bitch...
# 8672  This is just what the doctor ordered Put a gol...
# 8673  Look at ya  look at ya  look at ya  look at ya...
#
# [5778 rows x 7 columns]

# %%
import csv

# %%
df_final[['song','artists','lyrics','genres']].to_csv('data/final_text_dataset.csv',index=False,encoding='utf-8',escapechar="\\",quoting=csv.QUOTE_MINIMAL)
